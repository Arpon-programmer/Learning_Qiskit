# %% [markdown]
# # Do a Hello World example on a 2-qbit Bell state

# %% [markdown]
# ## Step 1: To map the problem to circuits and operators

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2)

qc.h(0)

qc.cx(0,1)

qc.draw(output='mpl')

# %%
from qiskit.quantum_info import Pauli

ZZ = Pauli('ZZ')
ZI = Pauli('ZI')
IZ = Pauli('IZ')
XX = Pauli('XX')
XI = Pauli('XI')
IX = Pauli('IX')

observables = [ZZ,ZI,IZ,XX,XI,IX]

# %% [markdown]
# ## Step 2: Optimize

# %% [markdown]
# ## Step 3: Execute on backend

# %%
from qiskit_aer.primitives import Estimator

estimator = Estimator()

job = estimator.run([qc]*len(observables),observables)

job.result()
# Out:
# EstimatorResult(values=array([1.        , 0.02929688, 0.02929688, 1.        , 0.        ,
# ...

# %% [markdown]
# ## Step 4: Post-process (and ploting)

# %%
import matplotlib.pyplot as plt

data = ['ZZ','ZI','IZ','XX','XI','IX']
values = job.result().values

plt.plot(data,values,'-o')
plt.xlabel('Observable')
plt.ylabel('Expectation Value')
plt.show()

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
qc.draw('mpl')

# %%
from qiskit.quantum_info import Pauli
ZZ = Pauli('ZZ')
IZ = Pauli('IZ')
ZI = Pauli('ZI')
XX = Pauli('XX')
IX = Pauli('IX')
XI = Pauli('XI')
observables = [ZZ,IZ,ZI,XX,IX,XI]

# %%
from qiskit_aer.primitives import Estimator
estimator = Estimator()
job = estimator.run([qc]*len(observables),observables)
job.result()
# Out:
# EstimatorResult(values=array([1.        , 0.00585938, 0.00585938, 1.        , 0.01757812,
# ...

# %%
import matplotlib.pyplot as plt
data = ['ZZ','IZ','ZI','XX','IX','XI']
values = job.result().values
plt.plot(data,values,'-o')
plt.xlabel('Observable')
plt.ylabel('Expectation Value')
plt.show()

# %% [markdown]
# ## Extent the hello world example to an n-qubit GHZ state

# %% [markdown]
# ## Step 1: Map the problem to circuits and operaters

# %%
def get_qc_for_n_qubit_GHZ_state(n):
    qc = QuantumCircuit(n)
    qc.h(0)
    for i in range(n-1):
        qc.cx(i,i+1)
    return qc

n = 10
qc = get_qc_for_n_qubit_GHZ_state(n)
qc.draw(output='mpl')

# %%
def get_qc_for_n_qubit_GHZ_state(n):
    qc = QuantumCircuit(n)
    qc.h(0)
    for i in range(n-1):
        qc.cx(i,i+1)
    return qc

n = 5
qc = get_qc_for_n_qubit_GHZ_state(n)
qc.draw('mpl')

# %%
from qiskit.quantum_info import SparsePauliOp
